# %%
from pathlib import Path
import sys

project_root = Path.cwd()
if not (project_root / "data" / "dataloader.py").exists():
    project_root = project_root.parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from data.dataloader import get_data_loaders

import torch
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import numpy as np

# %%
train_loader, test_loader, dev_loader = get_data_loaders(
    base_path=project_root / "data" / "us2020data" / "data_clean",
    file_format="jsonl",                  # jsonl / csv / tsv / parquet
    text_column="CleanText",
    label_column="POTUS",
    candidates=["Joe Biden", "Donald Trump"],
    split_ratios=(0.8, 0.1, 0.1),
    batch_size=16,
    num_workers=0,
    seed=42,
    shuffle_train=True,
    return_metadata=False,                # set True to get (text, label, metadata)
)

texts, labels = next(iter(train_loader))
print("Batch size:", len(texts))
print("First text sample for NLP:", texts[0][:200], "...")
print("First sample label:", labels[0])
# Out:
# Batch size: 16
# First text sample for NLP: Amid the deep anguish and the activism we are seeing across the country as Americans speak out about the violence of systemic racism, this morning brought a reminder of the deep economic hurt being in ...
# First sample label: Joe Biden
